# %% [markdown]
# # Texts

# %%
import utilities
proof_texts_path = u"proof_texts/"
from os import listdir
from os.path import isfile, join
proof_files = [f for f in listdir(proof_texts_path) if isfile(join(proof_texts_path, f)) and f[0] != '.']
print str(len(proof_files)) + "  files"
# Out:
# 10  files

# %% [markdown]
# ## text #0

# %%
print utilities.loadText(proof_texts_path +  proof_files[0] )
# Out:
#   {b>20 Benefits You Get When You Start Taking Employee Feedback Seriously<b} {b>Listening to your employees is a powerful and disruptive thing to do, and it has the potential to transform the way you manage your organization.<b} Your employees crave feedback. Whether negative or positive – they want to know it all. Why? Because they want to know how they can be better employees. Because getting a clear picture of performance helps identify weaknesses to be improved as well as strengths that can be leveraged. Because being heard makes employees feel valued. This feedback goes both ways, too. You stand to {1>learn as much from your employee’s<1} and they do from you. Which is another important reason to take what they say seriously. Employee feedback makes a huge impact on engagement. Managers giving little or no feedback fail to engage up to 98% of their work force. So, voice of the employee is critical to business. There are many benefits. Here's 20 of them: 1. You motivate better p
# ...

# %% [markdown]
# ## text #1

# %%
print utilities.loadText(proof_texts_path +  proof_files[1] )
# Out:
#   Assurance BibeliB Notice d’information et conditions générales de vente I-Go BibeliB Important ! {1>Veuillez lire attentivement ce document.<1} {b>SOMMAIRE<b} {b>TABLEAU DES MONTANTS DES GARANTIES<b}________________________________________{b>p.3-4<b} {b>NOTICE D’INFORMATION        <b}___________________________________________________{b>p.5<b} {b>DISPOSITIONS GENERALES<b}_____________________________________________________{b>p.6-12<b} {b>TABLEAU DES MONTANTS DES GARANTIES<b} {1}{b>BAGAGES<b} {b>Plafond de garantie<b} Montant assuré par valise équipée de la housse BibeliB {b>500 €<b} Plein par assuré et  par année d’assurance {b>500 €<b} Plein par évènement {b>20 000 €<b} {1}La société {2>MAPFRE ASISTENCIA<2}, Compañía Internacional de Seguros y Reaseguros, société anonyme de droit espagnol, au capital de 108.175.523,12 euros, dont le siège social est sis Carretera de Pozuelo nº52, 28222 Majadahonda, Madrid, Espagne, soumise dans le cadre de son activité, au contrôle des autorités 
# ...

# %% [markdown]
# ## text #2

# %%
print utilities.loadText(proof_texts_path +  proof_files[2] )
# Out:
#   Dans le cadre de nouvelle organisation et gouvernance du programme, nous mettons en place un suivi hebdomadaire des projets avec les différents Projects Managers. Vous trouverez ci-joint le template de reporting qu’il convient de compléter et de nous retourner au plus tard le 5 février, en prévision de la première réunion du 7 février. Je vous serai gré de respecter  autant que possible le format et la mise en page de ce template et reste à votre disposition pour plus de précisions.

# %% [markdown]
# ## text #3

# %%
print utilities.loadText(proof_texts_path +  proof_files[3] )
# Out:
#   Dossier : 20112049 05ème Pôle Chambre 02 R.G. : 15/16651 Signifiées le : {b>CONCLUSIONS II<b} {b>P O U R :<b} {u>la Société GEDEON RICHTER VEGYESZETI GYAR RT <u}   ayant son siège Gyömröi ut 19-21  1103 BUDAPEST HONGRIE, agissant en la personne de ses représentants légaux domiciliés en cette qualité audit siège {b>APPELANTE<b} {b>Ayant pouravocat constitué<b} {b>Maître Nathalie LESENECHAL<b} Avocat à la Cour Ayant pour avocat plaidant {b>SELAS CASALONGA AVOCATS<b} {b>Maître Arnaud CASALONGA<b} Avocat à la Cour {b>CONTRE :<b} {u>La S.A.S.<u} {u>MYLAN <u}    ayant son siège 117 allée des parcs   69800 SAINT PRIEST, prise en la personne de ses représentants légaux domiciliés en cette qualité audit siège {b>INTIMEE<b} {b>Maître Nadia BOUZIDI FABRE<b} Avocat à laCour {u>La S.A.S.<u} {u>LABORATOIRE HRA PHARMA <u}    ayant son siège 15 rue Béranger 75003 PARIS, prise en la personne de ses représentants légaux domiciliés en cette qualité audit siège {b>INTIMEE<b} {b>Maître Olivier BERNABE<
# ...

# %% [markdown]
# ## text #4

# %%
print utilities.loadText(proof_texts_path +  proof_files[4] )
# Out:
#   {b>Le concept de présence:<b} Récemment, des chercheurs ont commencé à réaliser que le sentiment de présence (Biocca, 1997; Lombard et Ditton, 1997; Lombard et al., 2000) est au centre de toutes les expériences médiées. Le cœur du désir de l'homme à utiliser les médias est de briser les limites du corps et les canaux sensoriels, ainsi le concept de présence est devenue l'un des axes de l'évolution de tous les médias (Biocca et al., 1995;. Lombard et Ditton, 1997). {1>Comme les technologies de simulation des interactions avec les gens et les lieux sont devenues plus sophistiqués<1}, {2>des informaticiens, des psychologues et des chercheurs en communication ont accordé encore plus d'attention à ce concept<2}. {3>Par conséquent<3}, la présence {4>est devenue centrale dans la théorisation à propos des interfaces homme-machine avancées telles que la réalité virtuelle (<4}VR) {5>systèmes (<5}Biocca, {6>1997; Lombard et Ditton<6}, 1997; {7>Sheridan<7}, 1995; {8>Steuer<8}, {9>1992; Whitmer
# ...

# %% [markdown]
# ## text #5

# %%
print utilities.loadText(proof_texts_path +  proof_files[5] )
# Out:
#   Vivez les belles histoires sur azaliza se connecter accueil découvrir azaliza bientôt mariés bientôt parents bientôt la fête exemples tarifs créer un site et une liste de cadeaux consulter un site et faire un cadeau plan du site conditions générales conditions particulières confidentialité mentions légales En poursuivant sur ce site, vous acceptez l'utilisation de cookies afin de faciliter votre navigation. En savoir plus Créez un ite web personnalisé pour chaque grande occasion imaginez une liste de cadeaux avec tout ce dont vous rêvez Un jour pas comme les autres arrive bientôt ! azaliza vous propose... Un site internet à vos couleurs Créez un site internet pour l'occasion et partagez avec vos proches la joie de votre heureux évènement Personnalisez en quelques clics un site zaliza sans publicité qui vous est entièrement dédié Ajoutez vos textes et vos photos, un livre d'or et les informations utiles pour tout partager avec vos proches Vivez toute l'intensité de votre évènement s
# ...

# %% [markdown]
# ## text #6

# %%
print utilities.loadText(proof_texts_path +  proof_files[6] )
# Out:
#   Code des templiers Jacques de Molay tu seras vengé {1>Carnet de joueur<1} {1>Plan<1} Le temple du mal Cellule Alcôve Point d'intérêt {1>Histoire<1} Vous faites partie d'une organisation occulte. Vous avez découvert qu'un portail, situé dans les caves Saint Sabin, relie notre époque à l’année 1347. Ce portail conduit dans l'ofﬁce d'un inquisiteur. Une ambiance proprement maléﬁque y règne. L ’inquisiteur est retrouvé mort, tandis que les détenus et les hérétiques sont libres d’aller et venir.Dans une heure, le portail sera déﬁnitivement scellé et condamnera l’humanité toute entière. Oserez-vous vous aventurer dans les geôles de l’inquisiteur et repousser l’Antéchrist ? {1>Objectifs<1} Résoudre les 3 séries (noir, blanc et rouge) d’énigmes pour accéder aux 3 jarres gardées par le bourreau. Dans chaque jarre, récupérer une information sur l’objet magique. A l’aide des 3 informations, trouver l’objet magique et fermer le portail. Tenter d’être plus rapide que les autres équipes. {1>Règl
# ...

# %% [markdown]
# ## text #7

# %%
print utilities.loadText(proof_texts_path +  proof_files[7] )
# Out:
#   ALNOOR , Français d’origine indienne, Alnoor dessine des objets marqués de Sens qui explore la part symbolique des objets et s’adresse directement à notre sphère émotionnelle. Son  travail a été récompensé par de nombreux prix et ses premières incursions dans le monde de l’art, se sont faites remarquées à la Foire de Miami/Art Basel. Ces pièces uniques enchantent autant les collectionneurs d’art contemporains internationaux que les grands décorateurs parisiens . Egalement Passionné de parfum il signe des flacons pour Yves saint Laurent ou Hermès ! Alnoor aime à dire qu’il crée des Objets de convoitises ! {b>Quelques dates clés :<b} {b>2003 <b}–MUSÉE INTERNATIONNAL DE LA PARFUMERIE ( Grasse) acquisition de l’œuvre « 7 parfums de Péchés » , {b>2005<b} - label de {i>OBSERVEUR DU DESIGN<i} pour la lampe 1-2-3 Soleil GIOVANARDI ( milan) {b>2007<b} – {i>Prix Découverte MAISON & OBJETS<i} pour Kaktussimo, CRISTALLERIE DE VAL SAINT LAMBERT {b>2008<b} –MUSÉE D’ART MODERNE DE FRANCKFORT ( Al
# ...

# %% [markdown]
# ## text #8

# %%
print utilities.loadText(proof_texts_path +  proof_files[8] )
# Out:
#   Newsletter N°2 - 2d semestre 2014 {1>{2}<1} {1>Téléchargez la newsletter en PDF<1} Challenge Volant Vert 2014 {1} Ce challenge est un concours initié en 2013 par notre partenaire {1>TRANSDEV OUTREMER<1}. Ce concours est ouvert aux conducteurs des réseaux urbains et interurbains, qui exercent au sein de sociétés privées ou de SEM transport implantées en OUTREMER. Ainsi, la Martinique et Mayotte ont participé à l’édition 2014 représentés respectivement par la SEM CFTU et la société MATIS. Pas moins de 08 sociétés réunionnaises étaient en lice pour cette 2nde édition: CHARLES EXPRESS, SEMITTEL, SEMTO, SODIPARC, START OI, STOI, SEM ESTIVAL, TRANSPORTS MOOLAND. La finale qui s’est déroulée le 30 novembre dernier à Saint-Pierre sur le parking du Jumbo Score a vu concourir 21 candidats sur les 3 épreuves suivantes : Conduite et maniabilité sur circuit Freinage d’urgence avec critère de vitesse contrôlé par radar – minimum 25 Km/h Marche arrière avec arrêt adossé Les excellentes performanc
# ...

# %% [markdown]
# ## text #9

# %%
print utilities.loadText(proof_texts_path +  proof_files[9] )
# Out:
#   {b>Menu du site<b} {b>Accueil / A propos / Présentation / le groupe / Qui sommes-nous / le groupe en Espagne / Offres d’emploi / A vendre / A louer / Services / Prestations / estimation / Demande de location / Contact / en Espagne<b} {b>Présentation<b} 1995 : Création de la Régie du Mail – Flavio Brisotto {1>1998 :<1} Affiliation à la Société des Régisseurs de Genève {1>2000 :<1} Renforcement du management avec l’arrivée de deux associés Sylvie Brisotto et José Exposito {1>2005 :<1} Création du Courtage du Mail {1>2010 :<1} Naissance du Groupe Immobilier du Mail et rachat de la régie Jean Simonin SA  fondée en 1947 {1>2015 :<1} Création de Helvetic immo Depuis 1995, la Régie du Mail met son expérience de l’immobilier au service de la population genevoise, dans des domaines allant de la vente, à la location, à la copropriété ou, plus récemment, aux coopératives. Trois ans après sa création, en 1998, la Régie du Mail obtient l’affiliation à la Société des Régisseurs de Genève, premiè
# ...
